# %% [markdown]
# <a href="https://colab.research.google.com/github/kalyankalluri999/Academic-Projects/blob/main/Radha.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd

try:
  df = pd.read_csv('/content/Bitcoin_tweets.csv',
                 dtype={'column5': float, 'column6': float, 'column7': object, 'column12': bool}, na_values=['nan'],
                 low_memory=False, encoding='utf-8')
except pd.errors.ParserError as e:
    print(f"Error: {e}")
# Display unique values in columns 5, 6, 7, and 12
for col in [5, 6, 7, 12]:
    print(f"Column {col}: {df.iloc[:, col].unique()}")
# Out:
# Error: Error tokenizing data. C error: EOF inside string starting at row 1307270
# Column 5: ['7605' '1532' '332' ... '5182' '2075' nan]
# Column 6: ['4838' '25483' '924' ... '58509' '83951' nan]
# Column 7: ['False' 'True'
#  "@krakenfx  #ETH #BTC  If you want to become poor, please don't buy #Bitcoin Obviously not financial advice. https://t.co/RstLTzN2MX"
#  "Official ESHOP Airdrop. If You Missed Meme Token Rally, Don't Miss ESHOP.  Join Now: https://t.co/2dtf2Pqc55   Join our Telegram: https://t.co/aaOlDav2rT   @EShop_Token @elonmusk #cryptocurrency #BSC #Bitcoin #Ethereum #ETH #Airdrop #bounty #ESHOP  #Airdrops"
#  '@pufferswap Nice project\n\n@karnoto_hendrik \n@ayubcandra12 \n@put_nab \n\n#YieldFarming #Airdrop #Binance #Bitcoin #pancakeswap #BNB #cryptocurrency #DeFi #BTC #BinanceSmartChain #BSC\n#pufferswap #DeFi #bsc #bnb #bitcoin #cryto #Airdrop #Airdrop'
#  '#btc to the moon 🚀🚀 77774' '#btc to the moon 🚀🚀 46059'
# ...

# %%
df.head(10)
# Out:
#                                   user_name    user_location  \
# 0                             DeSota Wilson      Atlanta, GA
# 1                                  CryptoND              NaN
# 2                                 Tdlmatias  London, England
# 3                      Crypto is the future              NaN
# 4  Alex Kirchmaier 🇦🇹🇸🇪 #FactsSuperspreader           Europa
# 5                       ZerrBenz™ ⚔ ✪ 20732    Bkk, Thailand
# 6                               Bitcoin-Bot     Florida, USA
# 7                    Cryptocurrencies / EUR              NaN
# 8                                   Mikcoin              NaN
# 9                             DeSota Wilson      Atlanta, GA
#
#                                     user_description         user_created  \
# 0  Biz Consultant, real estate, fintech, startups...  2009-04-26 20:05:09
# 1  😎 BITCOINLIVE is a Dutch platform aimed at inf...  2019-10-17 20:12:10
# ...

# %%
print(df.columns)
print(df.shape)
# Out:
# Index(['user_name', 'user_location', 'user_description', 'user_created',
#        'user_followers', 'user_friends', 'user_favourites', 'user_verified',
#        'date', 'text', 'hashtags', 'source', 'is_retweet'],
#       dtype='object')
# (1109907, 13)

# %%
df.isnull().sum().sum() # missing values
# Out:
# 669774

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,7))
sns.heatmap(df.isna(), cmap='YlOrBr')
plt.title("Missing Values")
plt.show()

# %%
df['user_verified'].value_counts().head(n=10).plot.bar()

# %%
df['user_verified'].value_counts().head(n=10).plot.bar()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1109907 entries, 0 to 1109906
# Data columns (total 13 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   user_name         1109887 non-null  object
#  1   user_location     587624 non-null   object
#  2   user_description  982661 non-null   object
#  3   user_created      1109906 non-null  object
#  4   user_followers    1109906 non-null  float64
#  5   user_friends      1109906 non-null  object
#  6   user_favourites   1109906 non-null  object
#  7   user_verified     1109906 non-null  object
#  8   date              1109906 non-null  object
#  9   text              1109906 non-null  object
#  10  hashtags          1093107 non-null  object
#  11  source            1106541 non-null  object
#  12  is_retweet        1109855 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 110.1+ MB

# %%
df.describe()
# Out:
#        user_followers
# count    1.109906e+06
# mean     9.065291e+03
# std      1.189295e+05
# min      0.000000e+00
# 25%      4.400000e+01
# 50%      2.250000e+02
# 75%      1.448000e+03
# max      2.359728e+07
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['user_followers'].plot(kind='hist', bins=20, title='user_followers')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_1['user_followers'].plot(kind='line', figsize=(8, 4), title='user_followers')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
df['source'].value_counts().head(n=5).plot.bar()
# Out:
# <Axes: >
